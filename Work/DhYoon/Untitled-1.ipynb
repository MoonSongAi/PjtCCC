# %%
from OCR_anal import specialDicForOCR , execute_OCR


image_path = 'C:\\PjtCCC\\CroppedImage\\1f369963-8f23-44d4-85bb-8d744ee0bd69.jpg'
#image_path = 'C:\\PjtCCC\\Work\\HrBaek\\test_final_2.png'
#image_path = 'C:\\PjtCCC\\CroppedImage\\6cb109a0-c53b-4fd5-b312-4a4d472d74ad.jpg'

myDic = specialDicForOCR()

ret_image = execute_OCR(myDic , image_path)
ret_image
# Out:
# ['2,200mg', [(237, 399), (369, 400), (369, 432), (237, 431)]]
# ['0mg', [(563, 471), (628, 471), (628, 504), (563, 504)]]
# ['400mg', [(144, 504), (243, 504), (243, 538), (144, 538)]]
# 수정문장: 영양·기능 정보 [칼슘] 뼈와 치아 형성에 필요, 신경과 근육 기능 유지에 필요, 정상적인 혈액응고에 필요, 골다공증 발생 위험 감소에 도움을 줌 [마그네슘] 에너지 이용에 필요, 신경과 근육 기능 유지에 필요 [비타민D] 칼슘과 인이 흡수되고 이용되는데 필요, 뼈의 형성과 유지에 필요, 골다공증 발생 위험 감소에 도움을 줌 [비타민K] 뼈의 구성에 필요, 정상적인 혈액응고에 필요 [아연] 정상적인 면역기능에 필요, 정상적인 세포분열에 필요 1일 섭취량: 2정(2,200mg) 1일 섭취량 당 함량: 열량 0kcal, 탄수화물 1g미만(0 %), 단백질 0g(0%), 지방 0g(0%), 나트륨 0mg(0 %), 칼슘 400mg (57%), 마그네슘 200 mg(63%), 비타민D 10ug(100%), 비타민K 70 Hg(100%), 아연 8.5 mg(100%) ※ ( )안의 수치는 1일 영양성분기준치에 대한 비율임 제조번호 36 x 13 | 소비기한 까지
#
# 변경사항: '발생 위:험'를 '발생 위험'으로 수정하였습니다. '정상]'를 '정상적인'으로 수정하였습니다. '아 연'을 '아연'으로 수정하였습니다. 이외에 맞춤법 오류를 찾지 못했습니다.
# <PIL.Image.Image image mode=RGB size=1422x1204>

# %%
# 폰트 파일 경로
font_path = "./SUIT-ttf/SUIT-Light.ttf"

# 폰트 크기 설정
font_size = 20

# 폰트 객체 생성
font = ImageFont.truetype(font_path, font_size)

# 특정 문자의 높이 계산
char = '한'  # 원하는 문자
char_height = font.getlength(char)

print(f"문자 '{char}'의 높이: {char_height} 픽셀")
# Out:
# 문자 '한'의 높이: 17.484375 픽셀
