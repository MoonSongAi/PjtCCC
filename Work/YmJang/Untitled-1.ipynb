# %%
from OCR_anal import specialDicForOCR , execute_OCR

image_path = 'C:\\PjtCCC\\CroppedImage\\fbc14d5d-2237-4a16-9453-1269850c09f3.jpg'

myDic = specialDicForOCR()

ret_image = execute_OCR(myDic , image_path)
ret_image
# Out:
# ['0mg', [(303, 93), (340, 93), (340, 119), (303, 119)]]
# ['8.5mg', [(762, 93), (814, 93), (814, 119), (762, 119)]]
# 수정문장:
# 영양•기능 정보 프로바이오틱스: 유산균 증식 및 유해균 억제, 배변활동 원활 국제 작업을 도움을 줄 수 있음입니다. 아연은 정상적인 면역기능에 필요함이며, 또한 정상적인 세포분열에도 필요합니다. 1일 섭취량은 1포(2) 이며, 1일 섭취량당 함량은 다음과 같습니다: 열량은 6kcal, 탄수화물 1.6g(0%), 단백질 0g(0%), 지방 0g(0%), 나트륨 0mg(0%), 프로바이오틱스 수는 2,000,000,000(20억) CFU, 아연 8.5mg(100%)입니다. 괄호 안의 수치는 1일 영양성분기준치에 대한 비율임을 알려드립니다. 원료명 및 함량에 대해 설명드리겠습니다.
#
# 변경사항:
# 주어진 원문에 띄어쓰기가 잘못된 부분, 콤마 등의 기호가 잘못 사용된 부분이 있어 이를 수정하였습니다. 또한 일부 문법적 오류를 수정하였습니다. '-' 기호를 사용하여 항목이나 상세 정보를 구분하였습니다.
# <PIL.Image.Image image mode=RGB size=2000x600>

# %%
# OCR을 위한 사전 준비 작업
myDic = specialDicForOCR()

# 처리할 이미지 경로 목록
processing_list = ['C:\\PjtCCC\\CroppedImage\\fbc14d5d-2237-4a16-9453-1269850c09f3.jpg', 'C:\\PjtCCC\\CroppedImage\\f877ddfd-d263-433a-9c1e-77d692d5a42c.jpg']  # 실제 이미지 경로로 대체하세요

# processing_list에 있는 각 이미지 파일에 대해 OCR 실행
for image_path in processing_list:
    # OCR 함수 실행
    ret_image = execute_OCR(myDic, image_path)
    
    # 결과 이미지 출력
    print(ret_image)

# %%
# 폰트 파일 경로
font_path = "./SUIT-ttf/SUIT-Light.ttf"

# 폰트 크기 설정
font_size = 20

# 폰트 객체 생성
font = ImageFont.truetype(font_path, font_size)

# 특정 문자의 높이 계산
char = '한'  # 원하는 문자
char_height = font.getlength(char)

print(f"문자 '{char}'의 높이: {char_height} 픽셀")
# Out:
# 문자 '한'의 높이: 17.484375 픽셀
